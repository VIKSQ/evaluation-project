# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv')
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %% [markdown]
# inthis data all columns in continuous data in which one is target variables and others are dependent variables therefore we use
# this data to analysis

# %%
df.shape
# Out:
# (30, 17)

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
#again checking info
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
# lets chacking statisticsofour dataset
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# above dataset wee see thereis no null present in dataset columns
# 1) the mean of all columns is bell manner and not lower than standerd deviation hence its perfect
# 2) and also max value and half percentile are also in perfect manner not high or not low
# 3) all is right in this data hence proceed with this without worry

# %%
# checking the distribution through graph of data in each continuous coulmns
plt.figure(figsize=(15,12), facecolor='white')
plotnumber=1
for col in df.columns:
    if plotnumber<=16:
        ax=plt.subplot(4,4,plotnumber)
        sns.distplot(df[col],color='m')
        plt.xlabel(col,fontsize=12)
    plotnumber+=1
plt.show()

# %%
the dataset looks like descent enough and there no see the skewness in the data only minor skewness showing in cg columns

# %%
df.skew()#checking skewness od data
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %%
df['R']=np.cbrt(df['R'])

# %%
df.skew()
# Out:
# W      0.047089
# R      0.892970
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %%
#lets observe the relation ship graph between independent anddependent variable 
plt.figure(figsize=(15,12),facecolor='Green')
plotnumber=1

for column in df:
    if plotnumber<=16:
        ax= plt.subplot(4,4,plotnumber)
        plt.scatter(df[column],df['W'])
        plt.xlabel(column)
        plt.ylabel('wins')
    plotnumber+=1
plt.show()

# %% [markdown]
# we have seethat most of columns are strongly contribute to happiness score because the positive proportion is shown beetween target and dependent
# hence we put all columns to model

# %%
# checking correlation between features and target variable
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.439027 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.439027  1.000000  0.332282  0.483362  0.564836 -0.053415  0.675069
# AB  -0.087947  0.332282  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.483362  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.564836  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.053415  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.675069 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.398238 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.038776 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081242  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.048267  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.046518  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
plt.figure(figsize=(15,13), facecolor='white')
plotnumber=1
for col in df:
    if plotnumber<=16:
        ax=plt.subplot(4,4,plotnumber)
        sns.boxplot(df[col],palette='Set2_r')
        plt.xlabel(col,fontsize=12)
    plotnumber+=1
plt.show()

# %% [markdown]
# wee see that only four columns present in outliers hence its not much impact on data because our data set is too sort so that we
# done with this

# %%
from scipy.stats import zscore

out_features = df[['ERA','SHO','SV','R']]
z= np.abs(zscore(out_features))
z
# Out:
#          ERA       SHO        SV         R
# 0   0.506955  0.814629  1.671607  0.650959
# 1   0.254598  0.172800  0.249879  0.164710
# 2   0.641347  0.320914  0.654856  0.316685
# 3   0.053010  0.567771  0.784104  1.186544
# 4   1.531318  0.172800  1.042600  0.041117
# 5   0.350165  0.320914  1.171848  3.317778
# 6   0.165003  1.802057  0.637623  1.324315
# 7   0.209800  0.320914  0.008617  0.461454
# 8   0.484557  0.172800  2.188598  0.774111
# 9   0.792164  0.320914  0.396360  1.057861
# 10  0.635374  0.567771  0.249879  1.108108
# 11  0.865333  0.419657  0.525608  0.736464
# 12  0.036584  0.172800  0.379127  0.461803
# 13  0.456185  0.172800  0.249879  0.553097
# 14  0.411388  0.913371  1.947335  0.129483
# 15  2.276445  0.913371  2.447094  0.718602
# 16  1.671683  0.419657  1.413111  0.182299
# 17  1.335704  2.394514  0.637623  0.041117
# 18  0.724968  1.061486  0.396360  0.571411
# 19  0.836961  0.814629  1.042600  0.848392
# 20  1.178913  0.666514  0.896119  0.065488
# ...

# %%
#threshold=3
np.where(z>3)
# Out:
# (array([5], dtype=int64), array([3], dtype=int64))

# %%
# now removing data above zscore and creating new dataframe
df1 = df[(z<3).all(axis=1)]

df1.shape
# Out:
# (29, 17)

# %%
df1.corr().W.sort_values()
# Out:
# ERA   -0.826952
# RA    -0.823176
# ER    -0.815308
# 3B    -0.206737
# SB    -0.169503
# AB    -0.085780
# E     -0.072858
# H     -0.018360
# CG     0.029594
# SO     0.156469
# HR     0.245697
# 2B     0.384886
# R      0.396810
# BB     0.447513
# SHO    0.497526
# SV     0.749290
# W      1.000000
# Name: W, dtype: float64

# %%
#saperating variables into x and y
x=df1.drop('W',axis=1)
y= df1['W']

# %%
#scaling the featuresusing ss
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
X
# Out:
#            R        AB         H        2B        3B        HR        BB  \
# 0   0.955349  0.830084  1.738306  1.556538  1.010845 -0.765863 -1.536359
# 1   0.348400 -0.702831 -0.938698  0.201171  1.208917 -0.181389 -0.495021
# 2  -0.252490 -1.100253 -0.106656  1.733325 -0.276617 -0.697101  1.252941
# 3  -1.338270  0.233951 -0.359886 -0.800621 -0.474688 -0.869006 -1.145857
# 4   0.194128  1.255894  2.063888  0.908319  1.704094 -0.353293 -0.197495
# 5   1.795850  0.716535 -0.070480 -0.093474 -1.266972  1.743939  1.643442
# 6   0.718804 -0.447345 -0.558853 -1.625627 -1.167936  1.915843 -0.885522
# 7  -0.823461 -0.447345 -0.323710  0.260100  0.020490  0.196801 -0.550807
# 8   1.463254  1.752672  1.702131  1.202964  0.119526 -0.009484  0.230197
# 9   1.525975 -0.078310  0.327453  0.319029  0.020490  0.368705  0.695081
# 10  1.062078 -0.816380 -0.685468  0.260100 -0.573723  2.362794  0.378960
# 11 -0.433630 -1.412514 -1.264279 -1.802414 -1.068901  0.506228 -0.569402
# ...

# %%
X.shape
# Out:
# (29, 16)

# %%
#model building
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor as knn
from sklearn.svm import SVR

# %%
#then come to model initializing and training
maxacc=0
maxrs=0
for i in range(1,200):
    x_train, x_test, y_train, y_test= train_test_split(X, y, test_size= 0.30, random_state= i)
    lr= LinearRegression()
    lr.fit(x_train,y_train)
    pred= lr.predict(x_test)
    acc= r2_score(y_test,pred)
    if acc>maxacc:
        maxacc=acc
        maxrs= i
print('best accuracy is', maxacc, 'at random state', maxrs)
# Out:
# best accuracy is 0.9114220478700992 at random state 104

# %%
x_train, x_test, y_train, y_test= train_test_split(X, y, test_size= 0.30, random_state= 104)

# %%
rfc= RandomForestRegressor()
rfc.fit(x_train,y_train)
predrfc= rfc.predict(x_test)
predrfc1= rfc.predict(x_train)
print('r2 score:\n',r2_score(y_test,predrfc))
print('r2 score on training data:\n', r2_score(y_train,predrfc1))
# Out:
# r2 score:
#  0.5706017647058825
# r2 score on training data:
#  0.928755533640149

# %%
knn1= knn(n_neighbors=3)
knn1.fit(x_train,y_train)
predknn= knn1.predict(x_test)
predknn2= knn1.predict(x_train)
print('r2 score:\n',r2_score(y_test,predknn))
print('r2 score on training data:\n', r2_score(y_train,predknn2))
# Out:
# r2 score:
#  0.6517273576097106
# r2 score on training data:
#  0.7553388365354178

# %%
df1.tail()
# Out:
#      W         R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  \
# 25  92  8.737260  5385  1346  263  26  187  563  1258   59  595  553  3.44
# 26  84  8.862095  5565  1486  288  39  136  457  1159   93  627  597  3.72
# 27  79  8.962809  5649  1494  289  48  154  490  1312  132  713  659  4.04
# 28  74  8.662391  5457  1324  260  36  148  426  1327   82  731  655  4.09
# 29  68  9.032802  5572  1479  274  49  186  388  1283   97  844  799  5.04
#
#     CG  SHO  SV   E
# 25   6   21  47  75
# 26   7   18  41  78
# 27   1   12  44  86
# 28   1    6  41  92
# 29   4    4  36  95

# %%
knn1.predict(scaler.transform([[8.662391,5457,1324,260,36,148,426,1327,82,731,655,4.09,1,6,41,92]]))
# Out:
# array([75.66666667])

# %%
svr= SVR()
svr.fit(x_train,y_train)
predsv= svr.predict(x_test)
predsv1= svr.predict(x_train)
print('r2 score:\n',r2_score(y_test,predsv))
print('r2 score on training data:\n', r2_score(y_train,predsv1))
# Out:
# r2 score:
#  0.09016212900255993
# r2 score on training data:
#  0.23501616269601489

# %%
gbr=GradientBoostingRegressor()
gbr.fit(x_train,y_train)
predgbr= gbr.predict(x_test)
predgbr1= gbr.predict(x_train)
print('r2 score:\n',r2_score(y_test,predgbr))
print('r2 score on training data:\n', r2_score(y_train,predgbr1))
# Out:
# r2 score:
#  0.646314385003961
# r2 score on training data:
#  0.9999998920517723

# %%
#for checking crossval score for our models
from sklearn.model_selection import cross_val_score

score= cross_val_score(rfc,X,y,cv=5)
print(score)
print('mean :',score.mean())
print('differnce between r2 score and cross validation score is:\n',(r2_score(y_test,predrfc)-score.mean())*100)
# Out:
# [ 0.18661307 -5.29353947  0.55661949  0.43343246  0.88162205]
# mean : -0.6470504809691937
# differnce between r2 score and cross validation score is:
#  121.76522456750763

# %%
score= cross_val_score(knn1,X,y,cv=5)
print(score)
print('mean :',score.mean())
print('differnce between r2 score and cross validation score is:\n',(r2_score(y_test,predknn)-score.mean())*100)
# Out:
# [-0.2219697  -2.76754386  0.42255681  0.4284153   0.76316824]
# mean : -0.27507464136359233
# differnce between r2 score and cross validation score is:
#  92.6801998973303

# %%
score= cross_val_score(gbr,X,y,cv=3)
print(score)
print('mean :',score.mean())
print('differnce between r2 score and cross validation score is:\n',(r2_score(y_test,predgbr)-score.mean())*100)
# Out:
# [-2.12488496  0.64074446  0.73495496]
# mean : -0.24972851502977034
# differnce between r2 score and cross validation score is:
#  89.60429000337314

# %%
score= cross_val_score(lr,X,y,cv=3)
print(score)
print('mean :',score.mean())
print('differnce between r2 score and cross validation score is:\n',(r2_score(y_test,pred)-score.mean())*100)
# Out:
# [-0.6914414   0.3501725  -2.82188982]
# mean : -1.054386240098827
# differnce between r2 score and cross validation score is:
#  76.9839818883085
